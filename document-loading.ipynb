# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.2.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain) (6.0.1)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.31-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain)
#   Downloading langchain_core-0.2.11-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.83-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain)
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 kB 2.4 MB/s eta 0:00:0000:01
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading pydantic-2.8.0-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.4.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.8 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.0 (from pydantic<3,>=1->langchain)
#   Downloading pydantic_core-2.20.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain) (3.0.0)
# Downloading langchain-0.2.6-py3-none-any.whl (975 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 7.8 MB/s eta 0:00:00a 0:00:01m
# Downloading aiohttp-3.9.5-cp311-cp311-macosx_11_0_arm64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.2/390.2 kB 9.4 MB/s eta 0:00:00:00:01
# Downloading langchain_core-0.2.11-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 7.5 MB/s eta 0:00:00ta 0:00:01
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.83-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 6.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 11.2 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-2.8.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.20.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.4 MB/s eta 0:00:0000:0100:01
# Downloading SQLAlchemy-2.0.31-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-8.4.2-py3-none-any.whl (28 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 4.0 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading orjson-3.10.6-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 kB 7.6 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: tenacity, SQLAlchemy, pydantic-core, orjson, numpy, multidict, jsonpatch, frozenlist, annotated-types, yarl, pydantic, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.31 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.7.0 frozenlist-1.4.1 jsonpatch-1.33 langchain-0.2.6 langchain-core-0.2.11 langchain-text-splitters-0.2.2 langsmith-0.1.83 multidict-6.0.5 numpy-1.26.4 orjson-3.10.6 pydantic-2.8.0 pydantic-core-2.20.0 tenacity-8.4.2 yarl-1.9.4
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
env = {}

# read .env file and set variables
with open('.env') as f:
    for line in f:
        key, value = line.strip().split('=')
        env[key] = value

openai.api_key = env['OPEN_AI_KEY']
OPENAI_API_KEY = env['OPEN_AI_KEY']

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.35.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openai) (2.8.0)
# Requirement already satisfied: sniffio in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.0)
# Downloading openai-1.35.9-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 9.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: tqdm, distro, openai
# Successfully installed distro-1.9.0 openai-1.35.9 tqdm-4.66.4
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai
import sys

openai.api_key = env['OPEN_AI_KEY']

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-4.2.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.2.6-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.6 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (0.2.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (0.2.11)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (0.1.83)
# Requirement already satisfied: numpy<2,>=1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-community) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain<0.3.0,>=0.2.6->langchain-community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain<0.3.0,>=0.2.6->langchain-community) (2.8.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain-community) (2.20.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.2.6-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.2.6 marshmallow-3.21.3 mypy-extensions-1.0.0 typing-inspect-0.9.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("docs/Lecture1.pdf")
pages = loader.load()

# %%
len(pages)
# Out:
# 39

# %%
page = pages[0]

# %%
print(page.page_content[0:500])
# Out:
# Introduction
# Welcome
# Machine Learning

# %%
page.metadata
# Out:
# {'source': 'docs/Lecture1.pdf', 'page': 0}

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
pip install yt_dlp
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2024.7.2-py3-none-any.whl.metadata (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.3/169.3 kB 6.8 MB/s eta 0:00:00
# Collecting brotli (from yt_dlp)
#   Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from yt_dlp) (2024.6.2)
# Collecting mutagen (from yt_dlp)
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pycryptodomex (from yt_dlp)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.32.2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from yt_dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from yt_dlp) (2.2.2)
# Collecting websockets>=12.0 (from yt_dlp)
#   Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2.32.2->yt_dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pikkuaapo/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests<3,>=2.32.2->yt_dlp) (3.7)
# Downloading yt_dlp-2024.7.2-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 6.1 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl (873 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.1/873.1 kB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 9.2 MB/s eta 0:00:00
# Downloading pycryptodomex-3.20.0-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt_dlp
# Successfully installed brotli-1.1.0 mutagen-1.47.0 pycryptodomex-3.20.0 websockets-12.0 yt_dlp-2024.7.2
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://github.com/basecamp/handbook/blob/master/37signals-is-you.md")

docs = loader.load()
print(docs[0].page_content[:500])
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# File not found · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation Menu
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
#           Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Product
#
#
#
#
#
#
#
#
#
#
#
#
#
# Actions
#         Automate any workflow
#
#
#
#
#
#
#
#
# Packages
#         Host and manage packages
#
#
#
#
#
#
#
#
# Security
#         Find and fix vulnerabilities
#
#
#
#
#
#
#
#
# Codespa
